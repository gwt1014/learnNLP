# %%
from aip import AipNlp
import pandas as pd
import time

# %%
""" 你的 APPID AK SK """
APP_ID = '11653919'
API_KEY = 'UvzTwOdwV2viviQ71VoEOigz'
SECRET_KEY = 'RbdwB9RvAAmv3jc4qRyPizeQGY7gWgSt '
client = AipNlp(APP_ID, API_KEY, SECRET_KEY)

# %%
options = {}
options["type"] = 13

# %%
f = open('jd行车记录仪评论2018-08-09.csv','rb')
df = pd.read_csv(f,encoding="utf-8")

# %%
content = df['content']

# %%
def geteachtextResult(commentList,errorlen = 0):
    banlist = []
    errorlist = []
    result = []
    print('共有%d条评论'%len(commentList))
    for text in commentList:
        nlp = client.commentTag(text,options)
        print('#',end='')
        if 'error_msg' in nlp:
            if nlp['error_code'] == 282130:
#                 print('不认识')
                errorlist.append(text)
            elif nlp['error_code'] == 18:
#                 print('ban')
                banlist.append(text)
            else:
                 print('未知错误')
                 print(nlp)
        elif 'items' in nlp:
            result.extend(nlp['items'])
        else:
            print('没报错但是也没结果')
            print(nlp)
    if len(banlist)!= 0:
#         a = copy.deepcopy(result)
        result.extend(geteachtextResult(banlist,errorlen+len(errorlist)))
        return result
#         return result.extend(geteachtextResult(banlist,errorlen+len(errorlist),result))
    else:
        print("\n分析完成！%d条没有结果"%(errorlen))
#         a = copy.deepcopy(result)
        return result

# %%
testComment = content[0:2000]
time1 = time.time()
com = geteachtextResult(testComment)
time2 = time.time()
print(str(time2-time1))
# Out:
# 共有2000条评论
# #########################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-321-e262ec80e60a> in <module>()
#       1 testComment = content[0:2000]
#       2 time1 = time.time()
# ----> 3 com = geteachtextResult(testComment)
#       4 time2 = time.time()
#       5 print(str(time2-time1))
#
# <ipython-input-290-611b1dc90803> in geteachtextResult(commentList, errorlen)
#       5     print('共有%d条评论'%len(commentList))
#       6     for text in commentList:
# ----> 7         nlp = client.commentTag(text,options)
#       8         print('#',end='')
#       9         if 'error_msg' in nlp:
#
# C:\ProgramData\Anaconda3\lib\site-packages\aip\nlp.py in commentTag(self, text, options)
#     172         data.update(options)
#     173
# --> 174         return self._request(self.__commentTagUrl, data)
#     175
#     176     def sentimentClassify(self, text, options=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\aip\base.py in _request(self, url, data, headers)
#      90             params = self._getParams(authObj)
#      91
# ---> 92             data = self._proccessRequest(url, params, data, headers)
#      93             headers = self._getAuthHeaders('POST', url, params, headers)
#      94             response = self.__client.post(url, data=data, params=params,
#
# C:\ProgramData\Anaconda3\lib\site-packages\aip\nlp.py in _proccessRequest(self, url, params, data, headers)
#      66             return json.dumps(data, ensure_ascii=False).decode('utf8').encode('gbk')
#      67         else:
# ---> 68             return json.dumps(data, ensure_ascii=False).encode('gbk')
#      69
#      70     def lexer(self, text, options=None):
#
# UnicodeEncodeError: 'gbk' codec can't encode character '\ufffd' in position 53: illegal multibyte sequence

# %%
result = pd.DataFrame(com)

# %%
count = result['prop'].value_counts()

# %%
count
# Out:
# 功能       8
# 质量       7
# 效果       6
# 东西       6
# 手机       5
# 外观       4
# 视频不错     3
# 分辨率      3
# 物流       3
# 屏幕       3
# 视频       3
# 操作       3
# 包装       3
# 手机不错     2
# 像素       2
# 看着       2
# 快递       2
# 发货       2
# 价格       2
# 性价       2
# 速度不错     2
# 做工       2
# 总体       2
# 速度       2
# 效果不错     2
# 质感不错     1
# 照片       1
# 质量不错     1
# 发热       1
# 接口一般     1
# 感觉       1
# 款式不错     1
# 拍照效果     1
# 视频清晰度    1
# 产品       1
# 外形       1
# 温度       1
# 画面效果     1
# 拍照不错     1
# 质感       1
# 画质       1
# 画面       1
# 品质       1
# 清晰度      1
# 功能一般     1
# 反应       1
# 产品性价比    1
# 摄像头一般    1
# 角度       1
# 开机慢      1
# 服务       1
# 性价比      1
# 物流速度     1
# 摄像       1
# 发货速度     1
# 品牌不错     1
# Name: prop, dtype: int64

# %%
for i in com:
    print(len(i))
# Out:
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 119
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-162-5b50170c9760> in <module>()
#       1 for i in com:
# ----> 2     print(len(i))
#
# TypeError: object of type 'NoneType' has no len()

# %%
# Out:
# [{'abstract': '<span>看着还不错</span>',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '看着',
#   'sentiment': 2},
#  {'abstract': '<span>这个款式很喜欢</span>',
#   'adj': '',
#   'begin_pos': 0,
#   'end_pos': 14,
#   'prop': '款式不错',
#   'sentiment': 2},
#  {'abstract': '这个价位<span>像素一般</span>',
#   'adj': '一般',
#   'begin_pos': 8,
#   'end_pos': 16,
#   'prop': '像素',
#   'sentiment': 0},
#  {'abstract': '这个价位这个<span>效果还是不错</span>',
#   'adj': '不错',
#   'begin_pos': 12,
#   'end_pos': 24,
#   'prop': '效果',
#   'sentiment': 2},
#  {'abstract': '机子<span>发热量比较大</span>',
#   'adj': '大',
#   'begin_pos': 4,
#   'end_pos': 16,
#   'prop': '发热',
#   'sentiment': 0},
#  {'abstract': '夏天车内<span>温度很高</span>',
#   'adj': '高',
#   'begin_pos': 8,
#   'end_pos': 16,
#   'prop': '温度',
#   'sentiment': 2},
#  {'abstract': '京东<span>快递给力</span>依然',
#   'adj': '给力',
#   'begin_pos': 4,
#   'end_pos': 12,
#   'prop': '快递',
#   'sentiment': 2},
#  {'abstract': '<span>视频回放带车速这个不错</span>',
#   'adj': '',
#   'begin_pos': 0,
#   'end_pos': 22,
#   'prop': '视频不错',
#   'sentiment': 2},
#  {'abstract': '<span>手机可以升级</span>',
#   'adj': '',
#   'begin_pos': 0,
#   'end_pos': 12,
#   'prop': '手机不错',
#   'sentiment': 2},
#  {'abstract': '重点录像和<span>拍照效果不错</span>?值这个价',
#   'adj': '不错',
#   'begin_pos': 10,
#   'end_pos': 22,
#   'prop': '拍照效果',
#   'sentiment': 2},
#  {'abstract': '重点录像和拍照<span>效果不错</span>?值这个价',
#   'adj': '不错',
#   'begin_pos': 14,
#   'end_pos': 22,
#   'prop': '效果',
#   'sentiment': 2},
#  {'abstract': '<span>京东送货速度就是快</span>',
#   'adj': '',
#   'begin_pos': 0,
#   'end_pos': 18,
#   'prop': '速度不错',
#   'sentiment': 2},
#  {'abstract': '<span>视频清晰</span>度也不错～',
#   'adj': '清晰',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '视频',
#   'sentiment': 2},
#  {'abstract': '<span>视频清晰度也不错</span>～',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 16,
#   'prop': '视频清晰度',
#   'sentiment': 2},
#  {'abstract': '<span>手机很好</span>连',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '手机',
#   'sentiment': 2},
#  {'abstract': '<span>视频清晰</span>没得说',
#   'adj': '清晰',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '视频',
#   'sentiment': 2},
#  {'abstract': '产品质量<span>做工都还可以</span>',
#   'adj': '还可以',
#   'begin_pos': 8,
#   'end_pos': 20,
#   'prop': '做工',
#   'sentiment': 2},
#  {'abstract': '价格合理<span>发货快</span>',
#   'adj': '快',
#   'begin_pos': 8,
#   'end_pos': 14,
#   'prop': '发货',
#   'sentiment': 2},
#  {'abstract': '<span>价格合理</span>发货快',
#   'adj': '合理',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '价格',
#   'sentiment': 2},
#  {'abstract': '<span>画面效果不错</span>',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 12,
#   'prop': '画面效果',
#   'sentiment': 2},
#  {'abstract': '画面<span>效果不错</span>',
#   'adj': '不错',
#   'begin_pos': 4,
#   'end_pos': 12,
#   'prop': '效果',
#   'sentiment': 2},
#  {'abstract': '<span>分辨率不错</span>',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '分辨率',
#   'sentiment': 2},
#  {'abstract': '记录仪样子<span>外观很时尚</span>',
#   'adj': '时尚',
#   'begin_pos': 10,
#   'end_pos': 20,
#   'prop': '外观',
#   'sentiment': 2},
#  {'abstract': '<span>拍照可以</span>',
#   'adj': '',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '拍照不错',
#   'sentiment': 2},
#  {'abstract': '录<span>视频也不错</span>',
#   'adj': '不错',
#   'begin_pos': 2,
#   'end_pos': 12,
#   'prop': '视频',
#   'sentiment': 2},
#  {'abstract': '大家关心的<span>分辨率还可以</span>',
#   'adj': '还可以',
#   'begin_pos': 10,
#   'end_pos': 22,
#   'prop': '分辨率',
#   'sentiment': 2},
#  {'abstract': '这个功能还是<span>手机好</span>用',
#   'adj': '不错',
#   'begin_pos': 12,
#   'end_pos': 18,
#   'prop': '手机',
#   'sentiment': 2},
#  {'abstract': '这个功能还是<span>手机好用</span>',
#   'adj': '好用',
#   'begin_pos': 12,
#   'end_pos': 20,
#   'prop': '手机',
#   'sentiment': 2},
#  {'abstract': '使用一个月下来综合360记录仪<span>功能齐全</span>',
#   'adj': '齐全',
#   'begin_pos': 27,
#   'end_pos': 35,
#   'prop': '功能',
#   'sentiment': 2},
#  {'abstract': '语音提示<span>功能很好</span>',
#   'adj': '不错',
#   'begin_pos': 8,
#   'end_pos': 16,
#   'prop': '功能',
#   'sentiment': 2},
#  {'abstract': '<span>快递给力</span>',
#   'adj': '给力',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '快递',
#   'sentiment': 2},
#  {'abstract': '<span>东西不错</span>',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '东西',
#   'sentiment': 2},
#  {'abstract': '<span>带的随车充电器只有一个usb接口</span>',
#   'adj': '',
#   'begin_pos': 0,
#   'end_pos': 29,
#   'prop': '接口一般',
#   'sentiment': 0},
#  {'abstract': '就是<span>像素不高</span>',
#   'adj': '不高',
#   'begin_pos': 4,
#   'end_pos': 12,
#   'prop': '像素',
#   'sentiment': 0},
#  {'abstract': '<span>总体来说还不错</span>',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 14,
#   'prop': '总体',
#   'sentiment': 2},
#  {'abstract': '<span>屏幕很小</span>',
#   'adj': '小',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '屏幕',
#   'sentiment': 0},
#  {'abstract': '<span>效果可以</span>',
#   'adj': '',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '效果不错',
#   'sentiment': 2},
#  {'abstract': '<span>好用好品质</span>',
#   'adj': '好用',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '品质',
#   'sentiment': 2},
#  {'abstract': '京东物流<span>速度快</span>',
#   'adj': '快',
#   'begin_pos': 8,
#   'end_pos': 14,
#   'prop': '速度',
#   'sentiment': 2},
#  {'abstract': '京东<span>物流速度快</span>',
#   'adj': '快',
#   'begin_pos': 4,
#   'end_pos': 14,
#   'prop': '物流速度',
#   'sentiment': 2},
#  {'abstract': '<span>电子狗功能不如单独的电子狗</span>',
#   'adj': '',
#   'begin_pos': 0,
#   'end_pos': 26,
#   'prop': '功能一般',
#   'sentiment': 0},
#  {'abstract': '<span>分辨率不错</span>看得清楚',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '分辨率',
#   'sentiment': 2},
#  {'abstract': '记录仪<span>外观时尚好看</span>',
#   'adj': '好看',
#   'begin_pos': 6,
#   'end_pos': 18,
#   'prop': '外观',
#   'sentiment': 2},
#  {'abstract': '记录仪<span>外观时尚</span>好看',
#   'adj': '时尚',
#   'begin_pos': 6,
#   'end_pos': 14,
#   'prop': '外观',
#   'sentiment': 2},
#  {'abstract': '<span>功能不错</span>',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '功能',
#   'sentiment': 2},
#  {'abstract': '<span>好用手机</span>连接方便直接查看',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '手机',
#   'sentiment': 2},
#  {'abstract': '<span>好用手机</span>连接方便直接查看',
#   'adj': '好用',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '手机',
#   'sentiment': 2},
#  {'abstract': '<span>效果还不错</span>',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '效果',
#   'sentiment': 2},
#  {'abstract': '<span>总体还是不错</span>的',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 12,
#   'prop': '总体',
#   'sentiment': 2},
#  {'abstract': '<span>很有质感</span>',
#   'adj': '',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '质感不错',
#   'sentiment': 2},
#  {'abstract': '<span>信任的品牌</span>',
#   'adj': '',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '品牌不错',
#   'sentiment': 2},
#  {'abstract': '<span>屏幕清晰</span>',
#   'adj': '清晰',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '屏幕',
#   'sentiment': 2},
#  {'abstract': '东西<span>质量很好</span>',
#   'adj': '不错',
#   'begin_pos': 4,
#   'end_pos': 12,
#   'prop': '质量',
#   'sentiment': 2},
#  {'abstract': '<span>可以看视频</span>',
#   'adj': '',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '视频不错',
#   'sentiment': 2},
#  {'abstract': '感觉很好<span></span>',
#   'adj': '好',
#   'begin_pos': 8,
#   'end_pos': 8,
#   'prop': '感觉',
#   'sentiment': 2},
#  {'abstract': '停车监控<span>功能很不错</span>',
#   'adj': '不错',
#   'begin_pos': 8,
#   'end_pos': 18,
#   'prop': '功能',
#   'sentiment': 2},
#  {'abstract': '有电子狗<span>功能狠实用</span>',
#   'adj': '实用',
#   'begin_pos': 8,
#   'end_pos': 18,
#   'prop': '功能',
#   'sentiment': 2},
#  {'abstract': '<span>操作也简单</span>',
#   'adj': '简单',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '操作',
#   'sentiment': 2},
#  {'abstract': '产品<span>质量好</span>',
#   'adj': '不错',
#   'begin_pos': 4,
#   'end_pos': 10,
#   'prop': '质量',
#   'sentiment': 2},
#  {'abstract': '东西<span>质感挺好</span>的',
#   'adj': '挺好',
#   'begin_pos': 4,
#   'end_pos': 12,
#   'prop': '质感',
#   'sentiment': 2},
#  {'abstract': '觉得这款<span>性价比比较高</span>',
#   'adj': '高',
#   'begin_pos': 8,
#   'end_pos': 20,
#   'prop': '性价比',
#   'sentiment': 2},
#  {'abstract': '觉得这款<span>性价比比较高</span>',
#   'adj': '高',
#   'begin_pos': 8,
#   'end_pos': 20,
#   'prop': '性价',
#   'sentiment': 2},
#  {'abstract': '东西是<span>好东西</span>',
#   'adj': '不错',
#   'begin_pos': 6,
#   'end_pos': 12,
#   'prop': '东西',
#   'sentiment': 2},
#  {'abstract': '<span>屏幕清晰</span>',
#   'adj': '清晰',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '屏幕',
#   'sentiment': 2},
#  {'abstract': '<span>物流超级快</span>',
#   'adj': '快',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '物流',
#   'sentiment': 2},
#  {'abstract': '<span>连接手机也挺方便的</span>',
#   'adj': '',
#   'begin_pos': 0,
#   'end_pos': 18,
#   'prop': '手机不错',
#   'sentiment': 2},
#  {'abstract': 'g300<span>外观比较小巧</span>',
#   'adj': '小巧',
#   'begin_pos': 4,
#   'end_pos': 16,
#   'prop': '外观',
#   'sentiment': 2},
#  {'abstract': '<span>功能比较实用</span>',
#   'adj': '实用',
#   'begin_pos': 0,
#   'end_pos': 12,
#   'prop': '功能',
#   'sentiment': 2},
#  {'abstract': '<span>质量也棒棒哒</span>',
#   'adj': '',
#   'begin_pos': 0,
#   'end_pos': 12,
#   'prop': '质量不错',
#   'sentiment': 2},
#  {'abstract': '视频<span>质量高</span>',
#   'adj': '高',
#   'begin_pos': 4,
#   'end_pos': 10,
#   'prop': '质量',
#   'sentiment': 2},
#  {'abstract': '<span>发货很及时</span>',
#   'adj': '及时',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '发货',
#   'sentiment': 2},
#  {'abstract': '清晰度不够<span></span>',
#   'adj': '不够',
#   'begin_pos': 10,
#   'end_pos': 10,
#   'prop': '清晰度',
#   'sentiment': 0},
#  {'abstract': '<span>看着不舒服</span>',
#   'adj': '不舒服',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '看着',
#   'sentiment': 0},
#  {'abstract': '<span>质量不错</span>',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '质量',
#   'sentiment': 2},
#  {'abstract': '<span>画面清晰</span>',
#   'adj': '清晰',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '画面',
#   'sentiment': 2},
#  {'abstract': '<span>产品不好</span>',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '产品',
#   'sentiment': 0},
#  {'abstract': '设计<span>做工还可以</span>',
#   'adj': '还可以',
#   'begin_pos': 4,
#   'end_pos': 14,
#   'prop': '做工',
#   'sentiment': 2},
#  {'abstract': '关键是<span>物流快</span>啊',
#   'adj': '快',
#   'begin_pos': 6,
#   'end_pos': 12,
#   'prop': '物流',
#   'sentiment': 2},
#  {'abstract': '<span>不错的东西</span>',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '东西',
#   'sentiment': 2},
#  {'abstract': '<span>送货速度很快</span>',
#   'adj': '',
#   'begin_pos': 0,
#   'end_pos': 12,
#   'prop': '速度不错',
#   'sentiment': 2},
#  {'abstract': '<span>操作简单</span>',
#   'adj': '简单',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '操作',
#   'sentiment': 2},
#  {'abstract': '感觉夜视<span>效果没有理想</span>的那么好',
#   'adj': '理想',
#   'begin_pos': 8,
#   'end_pos': 20,
#   'prop': '效果',
#   'sentiment': 2},
#  {'abstract': '但是<span>画质比较清晰</span>',
#   'adj': '清晰',
#   'begin_pos': 4,
#   'end_pos': 16,
#   'prop': '画质',
#   'sentiment': 2},
#  {'abstract': '停车监控<span>功能强大</span>',
#   'adj': '强大',
#   'begin_pos': 8,
#   'end_pos': 16,
#   'prop': '功能',
#   'sentiment': 2},
#  {'abstract': '录像拍出<span>照片十分清晰</span>',
#   'adj': '清晰',
#   'begin_pos': 8,
#   'end_pos': 20,
#   'prop': '照片',
#   'sentiment': 2},
#  {'abstract': '<span>360摄像头真不是吹的</span>',
#   'adj': '',
#   'begin_pos': 0,
#   'end_pos': 19,
#   'prop': '摄像头一般',
#   'sentiment': 0},
#  {'abstract': '总结一下<span>产品性价比非常高</span>',
#   'adj': '高',
#   'begin_pos': 8,
#   'end_pos': 24,
#   'prop': '产品性价比',
#   'sentiment': 2},
#  {'abstract': '总结一下产品<span>性价比非常高</span>',
#   'adj': '高',
#   'begin_pos': 12,
#   'end_pos': 24,
#   'prop': '性价',
#   'sentiment': 2},
#  {'abstract': '<span>还可以角度</span>大使用方便记录清晰拍摄清晰白天清晰电线够长一般',
#   'adj': '还可以',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '角度',
#   'sentiment': 2},
#  {'abstract': '收到的时候<span>包装完整</span>',
#   'adj': '完整',
#   'begin_pos': 10,
#   'end_pos': 18,
#   'prop': '包装',
#   'sentiment': 2},
#  {'abstract': '好厉害好东西便宜而且<span>质量好</span>物美价廉',
#   'adj': '不错',
#   'begin_pos': 20,
#   'end_pos': 26,
#   'prop': '质量',
#   'sentiment': 2},
#  {'abstract': '<span>包装很好</span>',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '包装',
#   'sentiment': 2},
#  {'abstract': '<span>服务还可以</span>',
#   'adj': '还可以',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '服务',
#   'sentiment': 2},
#  {'abstract': '<span>操作简单</span>',
#   'adj': '简单',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '操作',
#   'sentiment': 2},
#  {'abstract': '<span>效果高清</span>',
#   'adj': '',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '效果不错',
#   'sentiment': 2},
#  {'abstract': '<span>东西还挺好</span>',
#   'adj': '挺好',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '东西',
#   'sentiment': 2},
#  {'abstract': '<span>视频拍得也很清晰</span>',
#   'adj': '',
#   'begin_pos': 0,
#   'end_pos': 16,
#   'prop': '视频不错',
#   'sentiment': 2},
#  {'abstract': '<span>东西还不错</span>',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '东西',
#   'sentiment': 2},
#  {'abstract': '<span>好在东西</span>完好无损',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '东西',
#   'sentiment': 2},
#  {'abstract': '关键是<span>物流快</span>啊',
#   'adj': '快',
#   'begin_pos': 6,
#   'end_pos': 12,
#   'prop': '物流',
#   'sentiment': 2},
#  {'abstract': '<span>效果不错</span>',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '效果',
#   'sentiment': 2},
#  {'abstract': '手机上看<span>摄像也很清晰</span>',
#   'adj': '清晰',
#   'begin_pos': 8,
#   'end_pos': 20,
#   'prop': '摄像',
#   'sentiment': 2},
#  {'abstract': '就是连接手机操作<span>反应慢</span>',
#   'adj': '慢',
#   'begin_pos': 16,
#   'end_pos': 22,
#   'prop': '反应',
#   'sentiment': 0},
#  {'abstract': '<span>质量也不错</span>',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '质量',
#   'sentiment': 2},
#  {'abstract': '<span>开机有响声</span>',
#   'adj': '',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '开机慢',
#   'sentiment': 0},
#  {'abstract': '其他<span>功能到还可以</span>',
#   'adj': '还可以',
#   'begin_pos': 4,
#   'end_pos': 16,
#   'prop': '功能',
#   'sentiment': 2},
#  {'abstract': '卖家<span>发货速度快</span>',
#   'adj': '快',
#   'begin_pos': 4,
#   'end_pos': 14,
#   'prop': '发货速度',
#   'sentiment': 2},
#  {'abstract': '卖家发货<span>速度快</span>',
#   'adj': '快',
#   'begin_pos': 8,
#   'end_pos': 14,
#   'prop': '速度',
#   'sentiment': 2},
#  {'abstract': '<span>质量好</span>',
#   'adj': '不错',
#   'begin_pos': 0,
#   'end_pos': 6,
#   'prop': '质量',
#   'sentiment': 2},
#  {'abstract': '<span>价格低</span>',
#   'adj': '低',
#   'begin_pos': 0,
#   'end_pos': 6,
#   'prop': '价格',
#   'sentiment': 2},
#  {'abstract': '<span>外形也好看</span>',
#   'adj': '好看',
#   'begin_pos': 0,
#   'end_pos': 10,
#   'prop': '外形',
#   'sentiment': 2},
#  {'abstract': '<span>包装完好</span>',
#   'adj': '完好',
#   'begin_pos': 0,
#   'end_pos': 8,
#   'prop': '包装',
#   'sentiment': 2},
#  [...],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
result = []
banlist = []
errorlist = []
time1 = time.time()
print('共有%d条评论'%len(content))
for text in content[0:20]:
    nlp = client.commentTag(text,options)

    if 'items' in nlp:
        result.extend(nlp['items'])
    elif nlp['error_code'] == 18:
        banlist.append(text)
        print(nlp)
    else :
        print(nlp)
        errorlist.append(text)
#     print("#",end = '')
time2 = time.time()
commentResult = pd.DataFrame(result)
print("\n分析完成！用时%.2f秒，%d条没有结果"%(time2-time1,len(errorlist)))
# Out:
# 共有60048条评论
# {'log_id': 2691681956535414091, 'error_code': 282130, 'error_msg': 'no result'}
# {'log_id': 3581957969595228216, 'error_code': 282130, 'error_msg': 'no result'}
# {'log_id': 364277721653831185, 'error_code': 282130, 'error_msg': 'no result'}
# {'log_id': 8759266711191120854, 'error_code': 282130, 'error_msg': 'no result'}
# {'error_msg': 'Open api qps request limit reached', 'error_code': 18}
# {'error_msg': 'Open api qps request limit reached', 'error_code': 18}
# {'error_msg': 'Open api qps request limit reached', 'error_code': 18}
# {'error_msg': 'Open api qps request limit reached', 'error_code': 18}
# {'log_id': 4270143275667532614, 'error_code': 282130, 'error_msg': 'no result'}
# {'log_id': 6290018543247682925, 'error_code': 282130, 'error_msg': 'no result'}
#
# 分析完成！用时2.78秒，6条没有结果
