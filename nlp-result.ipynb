# %%
import pandas as pd
import jieba
import sys
import time
import jieba.posseg as pseg
import numpy as np

# %%
path = 'C:/Users/GWT/pyfiles/nlp/'

# %%
df = pd.read_csv(path + 'datasource/jly.csv',encoding='gbk',header=None)
df.columns = ['comment','count']
df['count'].astype(int)
# Out:
# 0       1409
# 1        756
# 2        719
# 3        656
# 4        541
# 5        368
# 6        361
# 7        344
# 8        327
# 9        303
# 10       288
# 11       274
# 12       273
# 13       243
# 14       238
# 15       234
# 16       232
# 17       229
# 18       177
# 19       155
# 20       152
# 21       149
# 22       136
# 23       136
# 24       134
# 25       132
# 26       132
# 27       130
# 28       128
# 29       118
#         ...
# 4356       1
# 4357       1
# 4358       1
# 4359       1
# 4360       1
# 4361       1
# 4362       1
# 4363       1
# 4364       1
# 4365       1
# 4366       1
# 4367       1
# 4368       1
# 4369       1
# 4370       1
# 4371       1
# 4372       1
# 4373       1
# 4374       1
# 4375       1
# 4376       1
# 4377       1
# 4378       1
# 4379       1
# 4380       1
# 4381       1
# 4382       1
# 4383       1
# 4384       1
# 4385       1
# Name: count, Length: 4386, dtype: int32

# %%
def getjieba_n(comment):
    txt = pseg.cut(comment)
    result = []
    for i in txt:
        if i.flag == "n":
            result.append(i.word)
    return "".join(result)

# %%
def getjieba_a(comment):
    txt = pseg.cut(comment)
    result = []
    for i in txt:
        if i.flag == "a":
            result.append(i.word)
    return "".join(result)

# %%
df['n']=df['comment'].map(lambda x: getjieba_n(x))

# %%
df['a'] =df['comment'].map(lambda x: getjieba_a(x))

# %%
df.replace('',np.NAN)
# Out:
#      comment  count     n    a
# 0      摄像头一般   1409   摄像头   一般
# 1       客服一般    756    客服   一般
# 2       内存一般    719    内存   一般
# 3        服务差    656   NaN    差
# 4       效果一般    541    效果   一般
# 5       功能一般    368    功能   一般
# 6       手机一般    361    手机   一般
# 7       质量一般    344    质量   一般
# 8       服务一般    327   NaN   一般
# 9        屏幕小    303    屏幕    小
# 10       物流慢    288    物流    慢
# 11      屏幕一般    274    屏幕   一般
# 12      价格实惠    273    价格  NaN
# 13      像素一般    243    像素   一般
# 14      视频一般    238    视频   一般
# 15       声音大    234    声音    大
# 16    拍摄效果不错    232    效果   不错
# 17       质量差    229    质量    差
# 18       开机慢    177    开机    慢
# 19      东西一般    155   NaN   一般
# 20       效果差    152    效果    差
# 21      安装麻烦    149   NaN  NaN
# 22       速度慢    136   速度慢  NaN
# 23      机器一般    136    机器   一般
# 24      电池一般    134    电池   一般
# 25       反应慢    132   NaN    慢
# 26       功能少    132    功能    少
# 27      态度不错    130    态度   不错
# 28      价格昂贵    128   NaN  NaN
# 29      画质一般    118    画质   一般
# ...      ...    ...   ...  ...
# 4356      客服      1    客服  NaN
# 4357     面料好      1    面料    好
# 4358     宝贝快      1   NaN    快
# 4359    力度不错      1    力度   不错
# 4360    工具不错      1    工具   不错
# 4361    套餐合适      1    套餐   合适
# 4362    颜色清晰      1    颜色   清晰
# 4363    拍照准确      1   NaN   准确
# 4364    银色好看      1    银色  NaN
# 4365    拿着方便      1   NaN   方便
# 4366    手法利索      1  手法利索  NaN
# 4367    包装细心      1    细心  NaN
# 4368    货品不错      1    货品   不错
# 4369    价格稳定      1    价格   稳定
# 4370  按键手感不错      1  按键手感   不错
# 4371  传输速度不错      1  传输速度   不错
# 4372  拍摄效果还好      1    效果  NaN
# 4373  机子外观漂亮      1  机子外观   漂亮
# 4374     切换好      1   NaN    好
# 4375    送货不错      1   NaN   不错
# 4376    功能管用      1    功能  NaN
# 4377    外观合适      1    外观   合适
# 4378    天气不热      1    天气    热
# 4379     像素满      1    像素    满
# 4380     回應快      1   NaN    快
# 4381    搭配挺好      1   NaN    好
# 4382    触屏也好      1    触屏  NaN
# 4383     内存高      1    内存    高
# 4384    画面还好      1    画面  NaN
# 4385    大气实用      1    大气  NaN
#
# [4386 rows x 4 columns]

# %%
result = df.groupby(['n']).sum().reset_index().sort_values('count',ascending=True)

# %%
result = result.drop(axis=1,index = 0)

# %%
result
# Out:
#          n  count
# 435     插孔      1
# 552   款型大方      1
# 245     外貌      1
# 557   死机垃圾      1
# 560    毛病力      1
# 561     气温      1
# 562     洋气      1
# 563     流速      1
# 565    流量力      1
# 570     滑轮      1
# 571      灯      1
# 573    灯光力      1
# 575     灰尘      1
# 231   外观性能      1
# 230   外观帅气      1
# 584  牌子不值钱      1
# 585   牌子垃圾      1
# 226   外观垃圾      1
# 550     模样      1
# 546   棱角分明      1
# 250    夜视力      1
# 251     大器      1
# 271   定位垃圾      1
# 521   机子温度      1
# 269     定价      1
# 268   存储空间      1
# 267     字迹      1
# 524  机子质量力      1
# 526   机身内存      1
# 264   妹子细心      1
# ..     ...    ...
# 594    物流力   1539
# 868   高端大气   1622
# 143     品牌   1846
# 130   发货速度   2003
# 412     手机   2139
# 284   客服态度   2250
# 127     发货   2360
# 14      产品   2396
# 398     总体   2513
# 43    价格便宜   2518
# 633     画质   2993
# 436    摄像头   3390
# 224     外观   3828
# 279     客服   3828
# 745     视频   4270
# 313     屏幕   4537
# 74      像素   4595
# 495   服务态度   5546
# 40      价格   5662
# 592     物流   5786
# 177     图像   5890
# 811     速度   5895
# 391    性价高   7083
# 103     功能   7496
# 566    清晰度   7634
# 388    性价比   8056
# 377     态度  11342
# 635     画面  13232
# 449     效果  20034
# 780     质量  26652
#
# [870 rows x 2 columns]

# %%
result.to_csv(path + 'output/sum.csv',encoding="gbk")

# %%
from pyecharts import Bar,WordCloud
from pyecharts_snapshot.main import make_a_snapshot

# %%
n = result[result['count']>5000]['n'].tolist()
count = result[result['count']>5000]['count'].tolist()
bar1 = Bar('行车记录仪关注点排序')
bar1.add("",n,count,is_convert =True)
bar1.render('bar1.html')
make_a_snapshot('bar1.html',path+'/output/jyl.png')
bar1
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="f488531d79d84f7293a670107d9139bd" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('f488531d79d84f7293a670107d9139bd'));
# var option =  {
#     "title": [
#         {
#             "text": "\u884c\u8f66\u8bb0\u5f55\u4eea\u5173\u6ce8\u70b9\u6392\u5e8f",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 5049349,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 5546,
#                 5662,
#                 5786,
#                 5890,
#                 5895,
#                 7083,
#                 7496,
#                 7634,
#                 8056,
#                 11342,
#                 13232,
#                 20034,
#                 26652
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5049349
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "type": "value"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 "\u670d\u52a1\u6001\u5ea6",
#                 "\u4ef7\u683c",
#                 "\u7269\u6d41",
#                 "\u56fe\u50cf",
#                 "\u901f\u5ea6",
#                 "\u6027\u4ef7\u9ad8",
#                 "\u529f\u80fd",
#                 "\u6e05\u6670\u5ea6",
#                 "\u6027\u4ef7\u6bd4",
#                 "\u6001\u5ea6",
#                 "\u753b\u9762",
#                 "\u6548\u679c",
#                 "\u8d28\u91cf"
#             ],
#             "type": "category"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart.setOption(option);
#
#     });
# </script>

# %%
n = result[result['count']>30]['n'].tolist()
count = result[result['count']>30]['count'].tolist()

cloud = WordCloud("词云")
cloud = WordCloud(width=900, height=600)
cloud.add('名词词云',n,count, word_size_range=[20,150],shape = 'star')
cloud.render('cloud.html')
make_a_snapshot('cloud.html',path+'/output/cloud.png')

cloud
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#          }
#     });
# </script>
# <div id="0381831057ca4f66a43e1b92ccdc2170" style="width:900px; height:600px;"></div>
#
# <script>
#     require([ 'echarts', 'wordcloud' ],function(ec){
# 	var myChart = ec.init(document.getElementById('0381831057ca4f66a43e1b92ccdc2170'));
# var option =  {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 2775998,
#     "tooltip": {},
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "\u540d\u8bcd\u8bcd\u4e91",
#             "shape": "star",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 150
#             ],
#             "data": [
#                 {
#                     "name": "\u7528\u6599",
#                     "value": 31,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(50,83,72)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6570\u636e",
#                     "value": 31,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(100,79,152)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u89c6\u9891\u6e05\u6670\u5ea6",
#                     "value": 32,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(89,30,41)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c4f\u5e55\u6e05\u6670\u5ea6",
#                     "value": 32,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(18,10,71)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7535\u5f71",
#                     "value": 32,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,67,124)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5927\u6c14",
#                     "value": 33,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(35,40,28)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5ba2\u670d\u6001\u5ea6\u70ed\u60c5",
#                     "value": 33,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(71,63,34)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u673a\u578b",
#                     "value": 33,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(76,121,150)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5927\u5c4f",
#                     "value": 35,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(17,22,38)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u753b\u9762\u611f",
#                     "value": 35,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(11,27,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8bed\u97f3",
#                     "value": 38,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(104,121,2)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9500\u91cf",
#                     "value": 38,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(18,39,29)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6b3e\u5f0f\u5927\u65b9",
#                     "value": 40,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(150,75,46)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4ea7\u54c1\u5783\u573e",
#                     "value": 41,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(146,46,71)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u56fe\u6848",
#                     "value": 42,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(145,5,40)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5929\u6c14\u70ed",
#                     "value": 42,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(24,22,67)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6e29\u5ea6",
#                     "value": 43,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(15,47,89)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c4f\u5e55\u5c3a\u5bf8",
#                     "value": 43,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(98,154,102)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7528\u5904",
#                     "value": 43,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(116,16,47)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6863\u6b21",
#                     "value": 44,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,152,80)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4ea7\u54c1\u6027\u4ef7\u6bd4",
#                     "value": 44,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(1,96,125)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7269\u54c1",
#                     "value": 46,
#                     "textStyle": {
#                         "normal": {
#                             "color":
